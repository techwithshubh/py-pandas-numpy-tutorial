# %%
import pandas as pd
circuits = pd.read_csv("./files/002 circuits.csv", index_col=0)
circuits.head()
# Out:
#             circuitRef                            name      location  \
# circuitId
# 1          albert_park  Albert Park Grand Prix Circuit     Melbourne
# 2               sepang    Sepang International Circuit  Kuala Lumpur
# 3              bahrain   Bahrain International Circuit        Sakhir
# 4            catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 5             istanbul                   Istanbul Park      Istanbul
#
#              country       lat        lng  alt  \
# circuitId
# 1          Australia -37.84970  144.96800   10
# 2           Malaysia   2.76083  101.73800   18
# 3            Bahrain  26.03250   50.51060    7
# 4              Spain  41.57000    2.26111  109
# 5             Turkey  40.95170   29.40500  130
#
#                                                          url
# circuitId
# 1          http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 2          http://en.wikipedia.org/wiki/Sepang_Internatio...
# ...

# %%
circuits.sort_values(by="country").head()
# Out:
#                circuitRef                            name      location  \
# circuitId
# 25                 galvez   Autódromo Juan y Oscar Gálvez  Buenos Aires
# 1             albert_park  Albert Park Grand Prix Circuit     Melbourne
# 29               adelaide         Adelaide Street Circuit      Adelaide
# 57                zeltweg                         Zeltweg        Styria
# 23         osterreichring                         A1-Ring     Spielburg
#
#              country      lat       lng  alt  \
# circuitId
# 25         Argentina -34.6943  -58.4593    8
# 1          Australia -37.8497  144.9680   10
# 29         Australia -34.9272  138.6170   58
# 57           Austria  47.2039   14.7478  676
# 23           Austria  47.2197   14.7647  678
#
#                                                          url
# circuitId
# 25         http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Os...
# 1          http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# ...

# %%
circuits.groupby("country").head(1)
# Out:
#                circuitRef                            name        location  \
# circuitId
# 1             albert_park  Albert Park Grand Prix Circuit       Melbourne
# 2                  sepang    Sepang International Circuit    Kuala Lumpur
# 3                 bahrain   Bahrain International Circuit          Sakhir
# 4               catalunya  Circuit de Barcelona-Catalunya        Montmeló
# 5                istanbul                   Istanbul Park        Istanbul
# 6                  monaco               Circuit de Monaco     Monte-Carlo
# 7              villeneuve       Circuit Gilles Villeneuve        Montreal
# 8             magny_cours   Circuit de Nevers Magny-Cours     Magny Cours
# 9             silverstone             Silverstone Circuit     Silverstone
# 10         hockenheimring                  Hockenheimring      Hockenheim
# 11            hungaroring                     Hungaroring        Budapest
# ...

# %% [markdown]
# Pending: Need to understand Pivot concept

# %% [markdown]
# concat, merge
# ```py
# In [20]: air_quality = pd.merge(air_quality, stations_coord, how="left", on="location")
#
# In [21]: air_quality.head()
# Out[21]:
#                     date.utc  ... coordinates.longitude
# 0  2019-05-07 01:00:00+00:00  ...              -0.13193
# 1  2019-05-07 01:00:00+00:00  ...               2.39390
# 2  2019-05-07 01:00:00+00:00  ...               2.39390
# 3  2019-05-07 01:00:00+00:00  ...               4.43182
# 4  2019-05-07 01:00:00+00:00  ...               4.43182
#
# [5 rows x 6 columns]
# ```

# %% [markdown]
# Multiple tables can be concatenated both column-wise and row-wise using the concat function.
#
# For database-like merging/joining of tables, use the merge function.

# %% [markdown]
# String methods are available using the str accessor.
#
# String methods work element-wise and can be used for conditional indexing.
#
# The replace method is a convenient method to convert values according to a given dictionary.
